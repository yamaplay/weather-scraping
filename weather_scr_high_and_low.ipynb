# %% [markdown]
# 札幌、秋田、新潟、東京、大阪、広島、高知、熊本、那覇

# %% [markdown]
# place_codeA　[14, 32, 54, 44, 62, 67, 74, 86, 91]

# %% [markdown]
# place_codeB [47412, 47582, 47604, 47662, 47772, 47765, 47893, 47819, 47936]

# %%
place_name = ["札幌", "秋田", "新潟", "東京", "大阪", "広島", "高知", "熊本", "那覇"]

place_codeA = [14, 32, 54, 44, 62, 67, 74, 86, 91]

place_codeB = [47412, 47582, 47604, 47662, 47772, 47765, 47893, 47819, 47936]

import requests
from bs4 import BeautifulSoup
import csv
import pandas as pd
import matplotlib.pylab as plt
base_url = "http://www.data.jma.go.jp/obd/stats/etrn/view/annually_s.php?prec_no=%s&block_no=%s&year=2021&month=1&day=1&view=p1"

# %%
def str2float(str):
  try:
    return float(str)
  except:
    return 0.0

# %%
if __name__ == "__main__":

    for place in place_name:
        All_list = [['年', '陸の平均気圧(hPa)', '海の平均気圧(hPa)', '降水量(mm)', '平均気温(℃)','最高気温(℃)', '最低気温(℃)', '平均湿度(%)']]
        print(place)
        index = place_name.index(place)
        
        r = requests.get(base_url%(place_codeA[index], place_codeB[index]))
        r.encoding = r.apparent_encoding
    
        soup = BeautifulSoup(r.text)
    
        rows = soup.findAll('tr', class_='mtx2')
        print(len(rows))
    
        for row in rows:
            data = row.findAll('td')
            rowData = []
            rowData.append(str(data[0].string))
            rowData.append(str2float(data[1].string))
            rowData.append(str2float(data[2].string))
            rowData.append(str2float(data[3].string))
            rowData.append(str2float(data[7].string))
            rowData.append(str2float(data[10].string))
            rowData.append(str2float(data[11].string))
            rowData.append(str2float(data[12].string))
            All_list.append(rowData)

        with open(place + '.csv', 'w') as file:
            writer = csv.writer(file, lineterminator='\n')
            writer.writerows(All_list)
# Out:
# 札幌
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_13124/464368279.py in <module>
#      27             All_list.append(rowData)
#      28
# ---> 29         with open(place + '.csv', 'w') as file:
#      30             writer = csv.writer(file, lineterminator='\n')
#      31             writer.writerows(All_list)
#
# PermissionError: [Errno 13] Permission denied: '札幌.csv'

# %%
import pandas as pd

df = pd.read_csv("熊本.csv", encoding="SHIFT_JIS")#ここでcsvの読み込み

plt.plot(df["年"],df["最高気温(℃)"])
plt.xlim([1980, 2020])

plt.ylim([30,40]) #ここでy軸の範囲を指定
plt.title("熊本 最高気温", fontname='MS Gothic')
# Out:
# Text(0.5, 1.0, '熊本 最高気温')

# %%
df = pd.read_csv("熊本.csv", encoding="SHIFT_JIS")#ここでcsvの読み込み

plt.plot(df["年"],df["最低気温(℃)"])
plt.xlim([1980, 2020])

plt.ylim([-10,10]) #ここでy軸の範囲を指定
plt.title("熊本 最低気温", fontname='MS Gothic')
# Out:
# Text(0.5, 1.0, '熊本 最低気温')

# %%
df = pd.read_csv("広島.csv", encoding="SHIFT_JIS")#ここでcsvの読み込み

plt.plot(df["年"],df["最高気温(℃)"])
plt.xlim([1980, 2020])

plt.ylim([30,40]) #ここでy軸の範囲を指定
plt.title("広島 最高気温", fontname='MS Gothic')
# Out:
# Text(0.5, 1.0, '広島 最高気温')

# %%
df = pd.read_csv("広島.csv", encoding="SHIFT_JIS")#ここでcsvの読み込み

plt.plot(df["年"],df["最低気温(℃)"])
plt.xlim([1980, 2020])

plt.ylim([-10,10]) #ここでy軸の範囲を指定
plt.title("広島 最低気温", fontname='MS Gothic')
# Out:
# Text(0.5, 1.0, '広島 最低気温')

# %%
df = pd.read_csv("高知.csv", encoding="SHIFT_JIS")#ここでcsvの読み込み

plt.plot(df["年"],df["最高気温(℃)"])
plt.xlim([1980, 2020])

plt.ylim([30,40]) #ここでy軸の範囲を指定
plt.title("高知 最高気温", fontname='MS Gothic')
# Out:
# Text(0.5, 1.0, '高知 最高気温')

# %%
df = pd.read_csv("高知.csv", encoding="SHIFT_JIS")#ここでcsvの読み込み

plt.plot(df["年"],df["最低気温(℃)"])
plt.xlim([1980, 2020])

plt.ylim([-10,10]) #ここでy軸の範囲を指定
plt.title("高知 最低気温", fontname='MS Gothic')
# Out:
# Text(0.5, 1.0, '高知 最低気温')

# %%
df = pd.read_csv("札幌.csv", encoding="SHIFT_JIS")#ここでcsvの読み込み

plt.plot(df["年"],df["最高気温(℃)"])
plt.xlim([1980, 2020])

plt.ylim([25,40]) #ここでy軸の範囲を指定
plt.title("札幌 最高気温", fontname='MS Gothic')
# Out:
# Text(0.5, 1.0, '札幌 最高気温')

# %%
df = pd.read_csv("札幌.csv", encoding="SHIFT_JIS")#ここでcsvの読み込み

plt.plot(df["年"],df["最低気温(℃)"])
plt.xlim([1980, 2020])

plt.ylim([-20,-5]) #ここでy軸の範囲を指定
plt.title("札幌 最低気温", fontname='MS Gothic')
# Out:
# Text(0.5, 1.0, '札幌 最低気温')

# %%
df = pd.read_csv("秋田.csv", encoding="SHIFT_JIS")#ここでcsvの読み込み

plt.plot(df["年"],df["最高気温(℃)"])
plt.xlim([1980, 2020])

plt.ylim([30,40]) #ここでy軸の範囲を指定
plt.title("秋田 最高気温", fontname='MS Gothic')
# Out:
# Text(0.5, 1.0, '秋田 最高気温')

# %%
df = pd.read_csv("秋田.csv", encoding="SHIFT_JIS")#ここでcsvの読み込み

plt.plot(df["年"],df["最低気温(℃)"])
plt.xlim([1980, 2020])

plt.ylim([-15,0]) #ここでy軸の範囲を指定
plt.title("秋田 最低気温", fontname='MS Gothic')
# Out:
# Text(0.5, 1.0, '秋田 最低気温')

# %%
df = pd.read_csv("新潟.csv", encoding="SHIFT_JIS")#ここでcsvの読み込み

plt.plot(df["年"],df["最高気温(℃)"])
plt.xlim([1980, 2020])

plt.ylim([30,40]) #ここでy軸の範囲を指定
plt.title("新潟 最高気温", fontname='MS Gothic')
# Out:
# Text(0.5, 1.0, '新潟 最高気温')

# %%
df = pd.read_csv("新潟.csv", encoding="SHIFT_JIS")#ここでcsvの読み込み

plt.plot(df["年"],df["最低気温(℃)"])
plt.xlim([1980, 2020])

plt.ylim([-15,0]) #ここでy軸の範囲を指定
plt.title("新潟 最低気温", fontname='MS Gothic')
# Out:
# Text(0.5, 1.0, '新潟 最低気温')

# %%
df = pd.read_csv("大阪.csv", encoding="SHIFT_JIS")#ここでcsvの読み込み

plt.plot(df["年"],df["最高気温(℃)"])
plt.xlim([1980, 2020])

plt.ylim([30,40]) #ここでy軸の範囲を指定
plt.title("大阪 最高気温", fontname='MS Gothic')
# Out:
# Text(0.5, 1.0, '大阪 最高気温')

# %%
df = pd.read_csv("大阪.csv", encoding="SHIFT_JIS")#ここでcsvの読み込み

plt.plot(df["年"],df["最低気温(℃)"])
plt.xlim([1980, 2020])

plt.ylim([-10,10]) #ここでy軸の範囲を指定
plt.title("大阪 最低気温", fontname='MS Gothic')
# Out:
# Text(0.5, 1.0, '大阪 最低気温')

# %%
df = pd.read_csv("東京.csv", encoding="SHIFT_JIS")#ここでcsvの読み込み

plt.plot(df["年"],df["最高気温(℃)"])
plt.xlim([1980, 2020])

plt.ylim([30,40]) #ここでy軸の範囲を指定
plt.title("東京 最高気温", fontname='MS Gothic')
# Out:
# Text(0.5, 1.0, '東京 最高気温')

# %%
df = pd.read_csv("東京.csv", encoding="SHIFT_JIS")#ここでcsvの読み込み

plt.plot(df["年"],df["最低気温(℃)"])
plt.xlim([1980, 2020])

plt.ylim([-10,10]) #ここでy軸の範囲を指定
plt.title("東京 最低気温", fontname='MS Gothic')
# Out:
# Text(0.5, 1.0, '東京 最低気温')

# %%
df = pd.read_csv("那覇.csv", encoding="SHIFT_JIS")#ここでcsvの読み込み

plt.plot(df["年"],df["最高気温(℃)"])
plt.xlim([1980, 2020])

plt.ylim([30,40]) #ここでy軸の範囲を指定
plt.title("那覇 最高気温", fontname='MS Gothic')
# Out:
# Text(0.5, 1.0, '那覇 最高気温')

# %%
df = pd.read_csv("那覇.csv", encoding="SHIFT_JIS")#ここでcsvの読み込み

plt.plot(df["年"],df["最低気温(℃)"])
plt.xlim([1980, 2020])

plt.ylim([0,20]) #ここでy軸の範囲を指定
plt.title("那覇 最低気温", fontname='MS Gothic')
# Out:
# Text(0.5, 1.0, '那覇 最低気温')
